# %% [markdown]
# ## Apply different operation

# %%
import pandas as pd 
df  = pd.read_csv('../dataset/Automobile_data.csv')
df.head(2)
# Out:
#    index      company   body-style  wheel-base  length engine-type num-of-cylinders  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible        88.6   168.8        dohc             four         111               21  13495.0
# 1      1  alfa-romero  convertible        88.6   168.8        dohc             four         111               21  16500.0

# %%
# maximum price
df.price.max()
df['price'].max()
# Out:
# 45400.0

# %%
df.price.mean()
# Out:
# 15387.0

# %%
df.describe() #Quickly printing statistics
# example we can sse price has 2 gaps
# Out:
# array([[<AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'wheel-base'}>],
#        [<AxesSubplot:title={'center':'length'}>,
#         <AxesSubplot:title={'center':'horsepower'}>],
#        [<AxesSubplot:title={'center':'average-mileage'}>,
#         <AxesSubplot:title={'center':'price'}>]], dtype=object)

# %% [markdown]
# ## apply codintion

# %%
df[df.horsepower>150] #df.horsepower>100 retruen true or false df[] retruen all rows which horsepower is meet this condition
# Out:
#     index        company   body-style  wheel-base  length engine-type num-of-cylinders  horsepower  average-mileage    price
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv              six         154               19  16500.0
# 10     13            bmw        sedan       103.5   189.0         ohc              six         182               16  30760.0
# 11     14            bmw        sedan       103.5   193.8         ohc              six         182               16  41315.0
# 12     15            bmw        sedan       110.0   197.0         ohc              six         182               15  36880.0
# 24     33         jaguar        sedan       113.0   199.6        dohc              six         176               15  32250.0
# 25     34         jaguar        sedan       113.0   199.6        dohc              six         176               15  35550.0
# ...

# %%
## find the row of maximum price
df[df.price == df.price.max()]
# Out:
#     index        company body-style  wheel-base  length engine-type num-of-cylinders  horsepower  average-mileage    price
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv            eight         184               14  45400.0

# %%
#find the company and body style which has maximum price of parts
df[['company','body-style']][df.price == df.price.max()]
#or
df[df.price == df.price.max()][['company','body-style']]
# Out:
#           company body-style
# 35  mercedes-benz    hardtop

# %%
## fill null value of each column avg of each column 
df = df.fillna(df.median())
df
# Out:
# C:\Users\Mehedi\Jupyter Notebook Projects\pandas-dataframe-and-visualization\pandaVenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#     index      company   body-style  wheel-base  length engine-type num-of-cylinders  horsepower  average-mileage    price
# 0       0  alfa-romero  convertible        88.6   168.8        dohc             four         111               21  13495.0
# 1       1  alfa-romero  convertible        88.6   168.8        dohc             four         111               21  16500.0
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv              six         154               19  16500.0
# 3       3         audi        sedan        99.8   176.6         ohc             four         102               24  13950.0
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'wheel-base'}>],
#        [<AxesSubplot:title={'center':'length'}>,
#         <AxesSubplot:title={'center':'horsepower'}>],
#        [<AxesSubplot:title={'center':'average-mileage'}>,
#         <AxesSubplot:title={'center':'price'}>]], dtype=object)
